# %%
import cv2 as cv
import os
# !pip install pydicom pymedphys
import pydicom

from google.colab import drive
drive.mount('/content/gdrive')

src_data_dir = "/content/gdrive/MyDrive/CBIS-DDSM"
dst_data_dir = "/content/gdrive/MyDrive/CBIS-DDSM-IMG"
#if not os.path.exists(dst_data_dir):
   # os.mdir(dst_data_dir)

#print(cur_dir)
for cur_dir, sub_folders, file_names in os.walk(src_data_dir):
    print(cur_dir)
    #print(sub_folders)
    # print(file_names)
    # print()
    for file_name in file_names:
       # print(file_name)
        if file_name.endswith(".dcm"):
            src_file_path = os.path.join(cur_dir, file_name)
            image = pydicom.read_file(src_file_path).pixel_array  # read dicom image and get image array
            dst_file_path = src_file_path.replace(src_data_dir, dst_data_dir).replace(".dcm", ".png")
            dst_dir = os.path.dirname(dst_file_path)
            if not os.path.exists(dst_dir):
                os.makedirs(dst_dir)
            print(src_file_path)
            print(image.shape)
            print(dst_file_path)
            print()
            # cv.imwrite(src_file_path[:-3]+"png", image)  # write png image
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 2.6 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 42.6 MB/s
# ...
#      |████████████████████████████████| 793 kB 62.5 MB/s
# ...
#      |████████████████████████████████| 380 kB 68.6 MB/s
# ...
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.28 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# ...

# %%
import cv2 as cv
import os
# !pip install pydicom pymedphys
import pydicom

from google.colab import drive
drive.mount('/content/gdrive')

src_data_dir = "/content/gdrive/MyDrive/CBIS-DDSM"
dst_data_dir = "/content/gdrive/MyDrive/CBIS-DDSM-IMG"
#if not os.path.exists(dst_data_dir):
   # os.mdir(dst_data_dir)

#print(cur_dir)
for cur_dir, sub_folders, file_names in os.walk(src_data_dir):
    print(cur_dir)
    #print(sub_folders)
    # print(file_names)
    # print()
    for file_name in file_names:
       # print(file_name)
        if file_name.endswith(".dcm"):
            src_file_path = os.path.join(cur_dir, file_name)
            image = pydicom.read_file(src_file_path).pixel_array  # read dicom image and get image array
            dst_file_path = src_file_path.replace(src_data_dir, dst_data_dir).replace(".dcm", ".png")
            dst_dir = os.path.dirname(dst_file_path)
            if not os.path.exists(dst_dir):
                os.makedirs(dst_dir)
            print(src_file_path)
            print(image.shape)
            print(dst_file_path)
            print()
            cv.imwrite(dst_file_path[:-3]+"png", image)  # write png image
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/CBIS-DDSM
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_MLO
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_MLO/07-20-2016-DDSM-NA-64824
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_MLO/07-20-2016-DDSM-NA-64824/1.000000-full mammogram images-84602
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_MLO/07-20-2016-DDSM-NA-64824/1.000000-full mammogram images-84602/1-1.dcm
# (5101, 2581)
# /content/gdrive/MyDrive/CBIS-DDSM-IMG/Mass-Training_P_00333_RIGHT_MLO/07-20-2016-DDSM-NA-64824/1.000000-full mammogram images-84602/1-1.png
#
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_CC
# /content/gdrive/MyDrive/CBIS-DDSM/Mass-Training_P_00333_RIGHT_CC/07-20-2016-DDSM-NA-15934
# ...
