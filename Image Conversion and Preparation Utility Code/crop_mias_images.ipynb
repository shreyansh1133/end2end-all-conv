# %%
import os

from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)

#src_data_dir = "/content/gdrive/MyDrive/polygence/datasets/mias/train/pos/"
#dst_data_dir = "/content/gdrive/MyDrive/polygence/datasets/mias1/train/pos/"

src_data_dir = "/content/gdrive/MyDrive/polygence/datasets/KAUMDS/pos/"
dst_data_dir = "/content/gdrive/MyDrive/polygence/datasets/KAUMDS/processed/pos/"

print("rahul")

from PIL import Image

#im = Image.open('/content/gdrive/MyDrive/polygence/astronaut_rect.bmp')


for cur_dir, sub_folders, file_names in os.walk(src_data_dir):
    #print(cur_dir)
    #print(sub_folders)
    #print(file_names)
    # print()
    for file_name in file_names:
        #print(file_name)

        im = Image.open(src_data_dir+file_name)  
        #imgGray = im.convert('L')
        #imgGray.save(dst_data_dir+file_name)
        #im.convert('L').crop((315, 0, 720, 1024)).save(dst_data_dir+file_name, quality=95)
        im.convert('L').save(dst_data_dir+file_name, quality=95)
# Out:
# Mounted at /content/gdrive
# rahul
